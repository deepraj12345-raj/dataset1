# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://www.squareyards.com/sale/property-for-sale-in-gurgaon")

# %%
print(page.text)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0,user-scalable=no" />
# <title>Property for Sale in Gurgaon | 12460+ Houses for Sale in Gurgaon</title>
# <meta name="description" content="Property for Sale in Gurgaon : Buy Best Residential / Commecercial Properties for Sale in Gurgaon  ✔️Flats ✔️Apartment ✔️Plot ✔️Villa ✔️Independent House ✔️Penthouse ✔️Residential Studio. Search for the best house for sale near me.">
# <meta name="keywords" content="">
# <meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE">
# <base href="">
# <link rel="icon" href="https://static.squareyards.com/ui-assets/images/favicon.ico" type="image/x-icon">
# <meta name="language" content="en-uk, english">
# <meta http-equiv="Content-Language" content="en">
# <meta name="author" content="SquareYards.com">
# <meta name="copyright" content="https://www.squareyards.com/">
# ...

# %%
soup = BeautifulSoup(page.content,"html.parser")

# %%
results = soup.find(id="dev_headeroverlay")
print(results.prettify())
# Out:
# <div id="dev_headeroverlay" style="width:100%;height:100vh;position:fixed;top:0;left:0;z-index:3;display:none;">
# </div>

# %%
ProjectName = soup.findAll(attrs  = {'class':'tileProjectName'})

# %%
ProjectName
# Out:
# [<a class="tileProjectName" onclick="helperJS.goToURL('https://www.squareyards.com/resale-2-bhk-extra-room-850-sq-ft-builder-floor-in-sai-homes/3876317',`target=_blank`)"> </a>,
#  <a class="tileProjectName" onclick="helperJS.goToURL('https://www.squareyards.com/resale-3-bhk-servant-room-1630-sq-ft-builder-floor-in-smart-world-orchard/3876667',`target=_blank`)"> Smart World Orchard</a>,
#  <a class="tileProjectName" onclick="helperJS.goToURL('https://www.squareyards.com/resale-3-bhk-1500-sq-ft-builder-floor-in-vijay-vihar-sector-30-gurgaon/3880553',`target=_blank`)"> </a>,
#  <a class="tileProjectName" onclick="helperJS.goToURL('https://www.squareyards.com/resale-3-bhk-1660-sq-ft-apartment-in-bestech-park-view-ananda/3876564',`target=_blank`)"> Bestech Park View Ananda</a>,
#  <a class="tileProjectName" onclick="helperJS.goToURL('https://www.squareyards.com/resale-3-bhk-1395-sq-ft-apartment-in-emaar-emerald-estate/3878366',`target=_blank`)"> Emaar Emerald Estate</a>,
# ...

# %%
priceandstatus = soup.findAll(attrs  = {'class':'tlPrjctDtl'})

# %%
priceandstatus[0].text.replace('\n','')
# Out:
# ' ₹ 47 Lac850 Sq.Ft.Built-up AreaReady To MovePossession Status '

# %%
area = soup.findAll(attrs  = {'class':'tlSqFt'})

# %%
area[0].text.replace('\n','')
# Out:
# '850 Sq.Ft.'

# %%
apartmenttype = soup.findAll(attrs  = {'class':'tlA'})

# %%
apartmenttype[0].text.replace('\n','')
# Out:
# ' 2 BHK Builder Floor For Sale in Sector 15'

# %%
data = [(url,priceandstatus,area,apartmenttype)]

# %%
data
# Out:
# [('https://www.squareyards.com/sale/property-for-sale-in-gurgaon',
#   [<div class="tlPrjctDtl DSE_Resale_D18" onclick="helperJS.goToURL('https://www.squareyards.com/resale-2-bhk-extra-room-850-sq-ft-builder-floor-in-sai-homes/3876317', `_blank`)">
#    <div class="projectFlex DSE_Resale_D18">
#    <div class="tlPrcBo DSE_Resale_D18"> <span class="tlPrc DSE_Resale_D18">
#    ₹ 47 Lac
#    </span>
#    </div>
#    <ul class="tlPrjctUl">
#    <li class="tlPrjctLi DSE_Resale_D18">
#    <div class="tlSqFt DSE_Resale_D18">850 Sq.Ft.</div>
#    <span class="tlPrjctLiNm DSE_Resale_D18">Built-up Area</span>
#    </li>
#    <li class="tlPrjctLi DSE_Resale_D18">
#    <div class="tlSqFt DSE_Resale_D18">Ready To Move</div>
#    <span class="tlPrjctLiNm DSE_Resale_D18">Possession Status</span> </li>
#    </ul>
#    </div>
#    </div>,
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(data,columns =['url','priceandstatus','area','apartmenttype'])

# %%
df
# Out:
#                                                  url  \
# 0  https://www.squareyards.com/sale/property-for-...
#
#                                       priceandstatus  \
# 0  [[\n, [\n, <div class="tlPrcBo DSE_Resale_D18"...
#
#                                                 area  \
# 0  [[850 Sq.Ft.], [Ready To Move], [1630 Sq.Ft.],...
#
#                                        apartmenttype
# 0  [[ , [\n2 BHK Builder Floor For Sale in Sector...

# %%
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr><td align="left" class="seoData" valign="middle"><span><a class="seoLink" href="https://www.squareyards.com/sale/property-for-sale-in-sohna-road-gurgaon" title="Sale in Sohna Road,Gurgaon">Sohna Road</a>(833)</span></td>
# <td align="left" class="seoData" valign="middle"><span><a class="seoLink" href="https://www.squareyards.com/sale/property-for-sale-in-sector-57-gurgaon" title="Sale in Sector 57,Gurgaon">Sector 57</a>(461)</span></td>
# <td align="left" class="seoData" valign="middle"><span><a class="seoLink" href="https://www.squareyards.com/sale/property-for-sale-in-rajendra-park-gurgaon" title="Sale in Rajendra Park,Gurgaon">Rajendra Park</a>(423)</span></td>
# ...

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td align="left" valign="middle" width="40%">
# <div class="miniTileBox DSE_Resale_D26">
# <div class="miniTileFigure DSE_Resale_D26"><img alt="" class="img-responsive lazy DSE_Resale_D26" data-src="https://img.squareyards.com/cdn-cgi/image/width=50,height=50,quality=80,fit=crop,gravity=auto,format=webp/secondaryPortal/637830380356965608-1603220233553355.jpg" height="50" width="50"/></div>
# <div class="miniTileBody DSE_Resale_D26">
# <div class="miniProjectName"></div>
# <div class="miniTileTitle DSE_Resale_D26">3 BHK Builder Floor</div>
# <span class="tileLocation DSE_Resale_D26">Bhim Nagar</span>
# </div>
# </div>
# </td>, <td align="left" valign="middle" width="15%">
# <span class="miniTilesquareFit DSE_Resale_D26">1000 Sq.Ft.</span>
# <span class="miniTileLabel DSE_Resale_D18">Built-up Area</span>
# </td>, <td align="left" valign="middle" width="25%">
# <div class="miniTileProjectStatus DSE_Resale_D18">Ready To Move</div>
# ...

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [
#
#
#
#
# 3 BHK Builder Floor
# Bhim Nagar
#
#
# ,
# 1000 Sq.Ft.
# Built-up Area
# ,
# Ready To Move
# Possession Status
# ,
#
# ₹ 55 Lac
#
# ]
# str

# %%
import pandas as pd 
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0  [Sohna Road(833), Sector 57(461), Rajendra Par...
# 1  [Sector 37d(291), Sector 72a(286), Palam Vihar...
# 2  [Krishna Colony(233), Sector 56(225), Sector 6...
# 3  [Badshahpur(214), Sector 37c(214), Sector 66(1...
# 4  [Sector 104(168), Sohna(160), Sector 43(153), ...
# 5  [Sector 48(150), Sector 50(147), Sector 52(146...
# 6  [Sushant Lok I(141), Sector 3(135), Dwarka Exp...
# 7  [Bhondsi(119), Sohna Sector 33(119), Sector 68...
# 8  [Sector 51(101), Salapur Khera Village(98), Si...
# 9  [Sohna Sector 36(95), Sector 49(91), Sohna Sec...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#                       0                           1                        2  \
# 0      [Sohna Road(833)              Sector 57(461)       Rajendra Park(423)
# 1      [Sector 37d(291)             Sector 72a(286)         Palam Vihar(263)
# 2  [Krishna Colony(233)              Sector 56(225)           Sector 65(223)
# 3      [Badshahpur(214)             Sector 37c(214)           Sector 66(186)
# 4      [Sector 104(168)                  Sohna(160)           Sector 43(153)
# 5       [Sector 48(150)              Sector 50(147)           Sector 52(146)
# 6   [Sushant Lok I(141)               Sector 3(135)   Dwarka Expressway(129)
# 7         [Bhondsi(119)        Sohna Sector 33(119)           Sector 68(103)
# 8       [Sector 51(101)   Salapur Khera Village(98)         Silani Chowk(97)
# 9  [Sohna Sector 36(95)               Sector 49(91)       Sohna Sector 4(91)
#
#                      3
# 0     Sector 70a(302)]
# 1     Sector 102(235)]
# 2      Sector 67(221)]
# 3      Sector 84(183)]
# ...

# %%
df1[0] = df1[0].str.strip('[')
df1.head(40)
# Out:
#                             0                           1  \
# 0             Sohna Road(833)              Sector 57(461)
# 1             Sector 37d(291)             Sector 72a(286)
# 2         Krishna Colony(233)              Sector 56(225)
# 3             Badshahpur(214)             Sector 37c(214)
# 4             Sector 104(168)                  Sohna(160)
# 5              Sector 48(150)              Sector 50(147)
# 6          Sushant Lok I(141)               Sector 3(135)
# 7                Bhondsi(119)        Sohna Sector 33(119)
# 8              Sector 51(101)   Salapur Khera Village(98)
# 9         Sohna Sector 36(95)               Sector 49(91)
# 10              Sector 92(89)              Sector 36a(87)
# 11              Sector 30(83)               Sector 23(81)
# 12               Sector 7(76)            Gandhi Nagar(75)
# 13   Ashok Vihar Phase ii(74)               Sector 81(74)
# 14              Sector 45(71)               Sector 55(70)
# ...
